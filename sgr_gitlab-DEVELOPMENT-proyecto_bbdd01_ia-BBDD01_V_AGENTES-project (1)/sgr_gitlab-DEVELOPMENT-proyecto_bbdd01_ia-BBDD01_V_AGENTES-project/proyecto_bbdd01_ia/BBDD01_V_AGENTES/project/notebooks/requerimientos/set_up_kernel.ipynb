# %%
# %%bash
# set -euo pipefail
#
# # ===== Parámetros =====
# K="kbd01"                                      # <- cambia aquí el nombre del kernel
# VENV="/home/jupyter/myenv/$K"
# PROXY="http://proxyserv.svb.lacaixa.es:8080/"  # <- proxy corporativo correcto (8080)
# ART_HOST="artifacts.cloud.caixabank.com"
# ART_USER="USER"                                # <- tu usuario Artifactory LA U EN MINUSCULA
# ART_PASS="password"                            # <- tu password Artifactory
#
# # ===== Proxy / NO_PROXY (como en tu empresa) =====
# export HTTPS_PROXY="$PROXY"
# export HTTP_PROXY="$PROXY"
# export https_proxy="$PROXY"
# export http_proxy="$PROXY"
# export NO_PROXY=".googleapis.com"
# export no_proxy="$NO_PROXY"
#
# # ===== pip (global, como vuestro snippet) =====
# pip config set global.index-url "https://${ART_USER}:${ART_PASS}@${ART_HOST}/artifactory/api/pypi/pypi-remote/simple"
# pip config set global.trusted-host "${ART_HOST}"
# # Asegura que el primer pip también use Artifactory
# export PIP_INDEX_URL="https://${ART_USER}:${ART_PASS}@${ART_HOST}/artifactory/api/pypi/pypi-remote/simple"
#
# # ===== venv + kernel =====
# python -m venv "$VENV"
# source "$VENV/bin/activate"
#
# python -m pip install --upgrade pip
# python -m pip install \
#   ipykernel jupyter \
#   numpy pandas python-dateutil \
#   google-cloud-aiplatform google-cloud-bigquery db-dtypes pyarrow \
#   altair plotly kaleido matplotlib seaborn ipywidgets tqdm \
#   pydantic tenacity requests google-cloud-bigquery-storage
#
# python -m ipykernel install --user --name "$K" --display-name "Python ($K)"
#
# echo
# echo "[DONE] Kernel instalado: Python ($K)"
# echo "       Venv: $VENV"
# Out:
# Writing to /home/jupyter/.config/pip/pip.conf
# Writing to /home/jupyter/.config/pip/pip.conf
# Looking in indexes: https://u0125307:****@artifacts.cloud.caixabank.com/artifactory/api/pypi/pypi-remote/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━�━━━━━━━�━ 0.0/1.8 MB ? eta -:--:--��━━━━━━━━━━━━━━━━━ 0.1/1.8 MB 1.3 MB/s eta 0:00:02��━━━━━━━━━━━━━━━━━ 0.1/1.8 MB 1.8 MB/s eta 0:00:01��━━━━━━━━━━━━━━━━━ 0.3/1.8 MB 2.6 MB/s eta 0:00:01��━━━━━━━━━━━━━━━━━ 0.6/1.8 MB 4.2 MB/s eta 0:00:01╸━━━━━━━━━━━ 1.3/1.8 MB 7.0 MB/s eta 0:00:01��━━━━━━━━━━━ 1.8/1.8 MB 8.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 23.0.1
#     Uninstalling pip-23.0.1:
#       Successfully uninstalled pip-23.0.1
# ...
# Looking in indexes: https://u0125307:****@artifacts.cloud.caixabank.com/artifactory/api/pypi/pypi-remote/simple
# ...

# %%
import google.auth
from vertexai import init
from google.cloud import bigquery

PROJECT_ID = "go-cxb-bcx-data9-dtwsgrp01"
REGION = "europe-west4"

creds, prj = google.auth.default()
print("ADC OK. Proyecto detectado:", prj)

init(project=PROJECT_ID, location=REGION)
bq = bigquery.Client(project=PROJECT_ID)
print(list(bq.query("SELECT 1 AS ok").result()))
# Out:
# ADC OK. Proyecto detectado: go-cxb-bcx-data9-dtwsgrp01
# [Row((1,), {'ok': 0})]
